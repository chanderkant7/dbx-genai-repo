# %%
import sys

def get_serverless_version() -> int:
  python_version = sys.version.split()[0]
  match python_version:
    case "3.10.12":
      return 1
    case "3.11.10":
      return 2
    # default to latest version
    case _:
      return 2

serverless_version = get_serverless_version()
print(serverless_version)
# Out:
# 2

# %%
requirements = f"/Users/csharm33/code/genai_dbx/Course2/course2/{serverless_version}/shim.txt"
constraints = f"/Users/csharm33/code/genai_dbx/Course2/course2/{serverless_version}/constraints.txt"

# %pip install -r $requirements -c $constraints
#dbutils.library.restartPython()
print("The kernel has been restarted and you can now run the notebook.")
# Out:
# Looking in indexes: https://chander_sharma33%40optum.com:****@centraluhg.jfrog.io/artifactory/api/pypi/cdc-pypi-vir/simple
# Requirement already satisfied: openai==1.75.0 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from -r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 1)) (1.75.0)
# Requirement already satisfied: httpx==0.28.1 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from -r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: pandas==1.5.3 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from -r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: pydantic==1.10.6 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from -r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 4)) (1.10.6)
# Requirement already satisfied: typing in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from -r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 5)) (3.7.4.3)
# Requirement already satisfied: dotenv==0.9.9 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from -r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 6)) (0.9.9)
# Requirement already satisfied: tenacity==8.2.2 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from -r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 7)) (8.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from openai==1.75.0->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from openai==1.75.0->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from openai==1.75.0->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: sniffio in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from openai==1.75.0->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from openai==1.75.0->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from openai==1.75.0->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: certifi in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from httpx==0.28.1->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 2)) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from httpx==0.28.1->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: idna in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from httpx==0.28.1->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 2)) (3.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from pandas==1.5.3->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from pandas==1.5.3->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 3)) (2026.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from pandas==1.5.3->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 3)) (2.4.6)
# Requirement already satisfied: python-dotenv in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from dotenv==0.9.9->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: h11>=0.16 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx==0.28.1->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: six>=1.5 in /Users/csharm33/code/genai_dbx/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3->-r /Users/csharm33/code/genai_dbx/Course2/course2/2/requirements.txt (line 3)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# The kernel has been restarted and you can now run the notebook.
